# %%
import numpy as np
import pandas as pd

# %%
match = pd.read_csv(r"matches.csv")
delivery = pd.read_csv(r"deliveries.csv")

# %%
match.head(10)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...

# %%
match.shape
# Out:
# (1095, 20)

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
total_score_df = delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2207   1426307       1         214
# 2209   1426309       1         159
# 2211   1426310       1         172
# 2213   1426311       1         175
# 2215   1426312       1         113
#
# [1095 rows x 3 columns]

# %%
match_df = match.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals',
    'Gujarat Titans',
    'Lucknow Super Giants'
]

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df['team1'] = match_df['team1'].replace({
    'Kings XI Punjab': 'Punjab Kings',
    'Delhi Daredevils': 'Delhi Capitals',
    'Deccan Chargers': 'Sunrisers Hyderabad'
})

match_df['team2'] = match_df['team2'].replace({
    'Kings XI Punjab': 'Punjab Kings',
    'Delhi Daredevils': 'Delhi Capitals',
    'Deccan Chargers': 'Sunrisers Hyderabad'
})

match_df['winner'] = match_df['winner'].replace({
    'Kings XI Punjab': 'Punjab Kings',
    'Delhi Daredevils': 'Delhi Capitals',
    'Deccan Chargers': 'Sunrisers Hyderabad'
})

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (948, 22)

# %%
match_df = match_df[match_df['method'].isna()]

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
delivery_df = match_df.merge(delivery,on='match_id')

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 227358   1426312    Chennai  Kolkata Knight Riders           113       2
# 227359   1426312    Chennai  Kolkata Knight Riders           113       2
# 227360   1426312    Chennai  Kolkata Knight Riders           113       2
# 227361   1426312    Chennai  Kolkata Knight Riders           113       2
# 227362   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['total_runs_y'] = pd.to_numeric(delivery_df['total_runs_y'], errors='coerce')
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df['balls_left'] = 126 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 227358   1426312    Chennai  Kolkata Knight Riders           113       2
# 227359   1426312    Chennai  Kolkata Knight Riders           113       2
# 227360   1426312    Chennai  Kolkata Knight Riders           113       2
# 227361   1426312    Chennai  Kolkata Knight Riders           113       2
# 227362   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna(0)
# Step 2: Convert only non-zero (player names) to 1 (actual dismissals)
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x: 1 if isinstance(x, str) and x != "0" else 0)
# Step 3: Compute cumulative wickets per match
delivery_df['wickets'] = 10 - delivery_df.groupby('match_id')['player_dismissed'].cumsum()
# Step 4: Display relevant columns to check
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 227358   1426312    Chennai  Kolkata Knight Riders           113       2
# 227359   1426312    Chennai  Kolkata Knight Riders           113       2
# 227360   1426312    Chennai  Kolkata Knight Riders           113       2
# 227361   1426312    Chennai  Kolkata Knight Riders           113       2
# 227362   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df = delivery_df[delivery_df['balls_left'] != 0]

# %%
delivery_df['crr'] = (delivery_df['current_score']*6)/(126 - delivery_df['balls_left'])

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#            batting_team     bowling_team        city  runs_left  balls_left  \
# 44003  Rajasthan Royals  Kings XI Punjab  Chandigarh        151          91
#
#        wickets  total_runs_x       crr       rrr  result
# 44003        8           195  7.542857  9.956044       0

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
final_df.rename(columns={
    'wickets': 'wickets_left',
    'total_runs_x': 'target'
}, inplace=True)

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                 batting_team           bowling_team        city  runs_left  \
# 184860        Mumbai Indians   Lucknow Super Giants      Mumbai         40
# 125000   Sunrisers Hyderabad        Kings XI Punjab  Chandigarh        171
# 189398        Delhi Capitals   Lucknow Super Giants      Mumbai        109
# 15268         Mumbai Indians        Deccan Chargers      Durban         84
# 29794       Delhi Daredevils        Deccan Chargers     Cuttack        137
# ...                      ...                    ...         ...        ...
# 182594   Sunrisers Hyderabad    Chennai Super Kings      Mumbai        102
# 206233          Punjab Kings    Chennai Super Kings     Chennai         83
# 102117   Sunrisers Hyderabad  Kolkata Knight Riders     Kolkata        125
# 203492  Lucknow Super Giants         Gujarat Titans     Lucknow         48
# 200556        Gujarat Titans           Punjab Kings  Chandigarh         64
#
#         balls_left  wickets_left  target       crr        rrr
# ...

# %%
print(X_train.isnull().values.any())  # Returns True if NaN exists, else False
# Out:
# False

# %%
X_train_numeric = X_train.apply(pd.to_numeric, errors='coerce')

# Check for infinite values
print(np.isinf(X_train_numeric).sum())  # True if any inf values exist
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets_left    0
# target          0
# crr             0
# rrr             0
# dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

trf = ColumnTransformer([
    ('encoder', OneHotEncoder(drop='first', sparse_output=False), ['batting_team', 'bowling_team', 'city']),
    ('scaler', StandardScaler(), ['runs_left', 'balls_left', 'wickets_left', 'target', 'crr', 'rrr'])
], verbose_feature_names_out=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
print("X_train columns:", X_train.columns.tolist())
# Out:
# X_train columns: ['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left', 'wickets_left', 'target', 'crr', 'rrr']

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(transformers=[('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city']),
#                                                  ('scaler', StandardScaler(),
#                                                   ['runs_left', 'balls_left',
#                                                    'wickets_left', 'target',
#                                                    'crr', 'rrr'])],
#                                    verbose_feature_names_out=False)),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8457063179151841

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.52663259, 0.47336741])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
delivery_df.rename(columns={
    'wickets': 'wickets_left',
    'total_runs_x': 'target'
}, inplace=True)


print("Available match IDs with inning == 2:")
print(delivery_df['match_id'].unique())
# Out:
# Available match IDs with inning == 2:
# [ 335982  335983  335984  335985  335986  335987  335988  335989  335990
#   335991  335992  335993  335994  335995  335996  335997  335998  335999
#   336000  336001  336003  336034  336004  336005  336006  336007  336008
#   336009  336010  336011  336013  336014  336015  336016  336017  336018
#   336020  336021  336023  336024  336026  336027  336028  336029  336031
#   336032  336033  336002  336035  336036  336037  336012  336019  336038
#   336039  336040  392181  392182  392184  392185  392188  392189  392190
#   392191  392192  392194  392195  392196  392197  392198  392199  392200
#   392201  392202  392203  392204  392205  392206  392207  392208  392209
#   392210  392211  392212  392213  392215  392216  392217  392218  392219
#   392220  392221  392222  392223  392224  392225  392226  392227  392228
#   392229  392230  392231  392232  392233  392234  392235  392236  392237
# ...

# %%
def match_progression(x_df, match_id, pipe):
    match = x_df[x_df['match_id'] == match_id]

    # Try ball==6, else take last ball of each over
    over_end = match[match['ball'] == 6]
    if over_end.empty:
        over_end = match.groupby('over').last().reset_index()

    # Rename to expected columns
    over_end = over_end.rename(columns={
        'wickets': 'wickets_left',
        'total_runs_x': 'target'
    })

    temp_df = over_end[['batting_team', 'bowling_team', 'city', 'runs_left',
                        'balls_left', 'wickets_left', 'target', 'crr', 'rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]

    if temp_df.empty:
        print("⚠️ No valid data for match_id", match_id)
        return pd.DataFrame(), None

    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0] * 100, 1)
    temp_df['win'] = np.round(result.T[1] * 100, 1)
    temp_df['end_of_over'] = range(1, temp_df.shape[0] + 1)

    target = temp_df['target'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0, target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)

    wickets = list(temp_df['wickets_left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0, 10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]

    print("Target-", target)
    temp_df = temp_df[['end_of_over', 'runs_after_over', 'wickets_in_over', 'lose', 'win']]
    return temp_df, target

# %%
temp_df, target = match_progression(delivery_df, 1136615  , pipe)
temp_df.head(20)
# Out:
# Target- 174
#         end_of_over  runs_after_over  wickets_in_over  lose   win
# 133902            1               13                1  49.8  50.2
# 133908            2                1                0  56.9  43.1
# 133914            3                3                0  59.2  40.8
# 133920            4               17                0  44.7  55.3
# 133926            5               16                0  32.3  67.7
# 133932            6                5                0  32.2  67.8
# 133940            7                6                1  44.5  55.5
# 133946            8                5                0  44.7  55.3
# 133952            9                8                1  55.4  44.6
# 133958           10                6                2  79.0  21.0
# 133964           11                6                0  78.9  21.1
# 133970           12               13                0  70.7  29.3
# 133976           13               13                0  59.6  40.4
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-174')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals',
#  'Gujarat Titans',
#  'Lucknow Super Giants']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', nan,
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai',
#        'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
